# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubinisuresh/Course_7_new/blob/main/Course_7_Week_2_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('auto-mpg.csv') # Reading the csv file
df.head(10)
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130  3504.0          12.0        70.0
# 1   15          8         350.0         165  3693.0          11.5        70.0
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
# 5   15          8         429.0         198  4341.0          10.0        70.0
# 6   14          8         454.0         220  4354.0           9.0        70.0
# 7   14          8         440.0         215  4312.0           8.5        70.0
# 8   14          8         455.0         225     NaN          10.0        70.0
# 9   15          8         390.0         190  3850.0           8.5        70.0
#
#    origin                   car name CAR Number
# 0       1  chevrolet chevelle malibu    L6V 043
# ...

# %%
#Remove unnecessary columns
# DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise’)
#axis=0  means row
#axis =1  means columns
df.drop(['origin'],axis=1,inplace=True)
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130  3504.0          12.0        70.0
# 1   15          8         350.0         165  3693.0          11.5        70.0
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
#
#                     car name CAR Number
# 0  chevrolet chevelle malibu    L6V 043
# 1          buick skylark 320     RTY079
# 2         plymouth satellite     MTP600
# 3              amc rebel sst     MNJ000
# 4                ford torino   JEETMEET

# %%
#Drop rows
df.drop([0,1],axis=0).head(3)
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
#
#              car name CAR Number
# 2  plymouth satellite     MTP600
# 3       amc rebel sst     MNJ000
# 4         ford torino   JEETMEET

# %%
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130  3504.0          12.0        70.0
# 1   15          8         350.0         165  3693.0          11.5        70.0
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
#
#                     car name CAR Number
# 0  chevrolet chevelle malibu    L6V 043
# 1          buick skylark 320     RTY079
# 2         plymouth satellite     MTP600
# 3              amc rebel sst     MNJ000
# 4                ford torino   JEETMEET

# %% [markdown]
# **FIND OUT ALL THE MISSING VALUES IN A DATASET**

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          3
# acceleration    2
# model year      2
# car name        0
# CAR Number      7
# dtype: int64

# %% [markdown]
# **Delete records wth missing values**
#
# DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
df.dropna(how='any',axis=0)

#all means all of the values in a column or row should be null/zero, only then it will get rid of that column / row
#any- means even if there are few null/zero values in a column/row, it will drop the entire row or column
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0         130  3504.0          12.0
# 1    15          8         350.0         165  3693.0          11.5
# 2    18          8         318.0         150  3436.0          11.0
# 3    16          8         304.0         150  3433.0          12.0
# 4    17          8         302.0         140  3449.0          10.5
# ..  ...        ...           ...         ...     ...           ...
# 92   13          8         351.0         158  4363.0          13.0
# 93   14          8         318.0         150  4237.0          14.5
# 94   13          8         440.0         215  4735.0          11.0
# 96   13          8         360.0         175  3821.0          11.0
# 97   18          6         225.0         105  3121.0          16.5
#
#     model year                      car name CAR Number
# 0         70.0     chevrolet chevelle malibu    L6V 043
# ...

# %% [markdown]
# **Pandas has .fillna() method**
#
# which accepts a value which we want to replace in place of NaN values. We just calculated mean of the column and passed it as an input argument to fillna() method
#
# DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
#
# df = df.fillna(0) #replacing NaN values with 0 for the entire dataframe
#
#
#
# df["col_name"] = df["col_name"].fillna("") #replacing NaN values with "" for the column "col_name"
#
#
#
# df[["col1","col2"]] = df[["col1","col2"]].fillna("") #replacing NaN values with "" for the columns "col1" and "col2"

# %%
df['acceleration'].mean()
# Out:
# 14.046875

# %%
df['acceleration'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# Name: acceleration, Length: 98, dtype: bool

# %%
df['acceleration'].fillna(df['acceleration'].mean(),inplace=True)
df['acceleration']
# Out:
# 0     12.0
# 1     11.5
# 2     11.0
# 3     12.0
# 4     10.5
#       ...
# 93    14.5
# 94    11.0
# 95    11.0
# 96    11.0
# 97    16.5
# Name: acceleration, Length: 98, dtype: float64

# %% [markdown]
# **Replace A Missing value**

# %%
df['car name'].replace("chevrolet chevelle malibu","chevrolet",inplace=True)
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130  3504.0          12.0        70.0
# 1   15          8         350.0         165  3693.0          11.5        70.0
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
#
#              car name CAR Number
# 0           chevrolet    L6V 043
# 1   buick skylark 320     RTY079
# 2  plymouth satellite     MTP600
# 3       amc rebel sst     MNJ000
# 4         ford torino   JEETMEET

# %% [markdown]
# **REMOVE DUPLICATES**

# %%
#Find and remove duplicate entries

#df[df['CAR Number'].duplicated()]  OR

df[df.duplicated(subset=['CAR Number'])]

# df[df.duplicated(subset=['CAR Number'])]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 17   15          8         383.0         170     NaN          10.0
# 26   10          8         307.0         200  4376.0          15.0
# 29   27          4          97.0          88  2130.0          14.5
# 32   25          4          98.0          80  2046.0          19.0
# 34   16          6         225.0         105  3439.0          15.5
# 52   30          4          88.0          76  2065.0          14.5
# 54   35          4          72.0          69  1613.0          18.0
# 73   13          8         307.0         130  4098.0          14.0
#
#     model year                          car name CAR Number
# 17        70.0               dodge challenger se     TN5678
# 26        70.0                         chevy c20        NaN
# 29        71.0                      datsun pl510        NaN
# 32        71.0                        ford pinto        NaN
# 34        71.0         plymouth satellite custom     JHGY59
# ...

# %%
df[df['CAR Number']=='JHGY59']
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 34   16          6         225.0         105  3439.0          15.5
#
#     model year  origin                   car name CAR Number
# 34        71.0       1  plymouth satellite custom     JHGY59

# %%
#~df['CAR Number'].duplicated(keep='first')
df.drop_duplicates(subset=['CAR Number'], keep='last',inplace=True)

#df['column name].drop_duplicates() will work only if duplicate  rows have al of the columns with similar values .
#otherwise use subset  ttribute.entire row

# %% [markdown]
# **Data Formatting**

# %%
#Renaming the column
#DataFrame.rename(columns={"id": "ID"}, inplace=True)
#DataFrame.rename(columns={"ID": "Student_ID", "name": "First_Name", "grade": "Average_Grade"}, inplace=True)

df.rename(columns={"car name":"carname"},inplace=True)
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130  3504.0          12.0        70.0
# 1   15          8         350.0         165  3693.0          11.5        70.0
# 2   18          8         318.0         150  3436.0          11.0        70.0
# 3   16          8         304.0         150  3433.0          12.0        70.0
# 4   17          8         302.0         140  3449.0          10.5        70.0
#
#    origin                    carname CAR Number
# 0       1  chevrolet chevelle malibu    L6V 043
# 1       1          buick skylark 320     RTY079
# 2       1         plymouth satellite     MTP600
# 3       1              amc rebel sst     MNJ000
# 4       1                ford torino   JEETMEET

# %%
#Correcting Datatype
df.dtypes
# Out:
# mpg               int64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# model year      float64
# origin            int64
# carname          object
# CAR Number       object
# dtype: object

# %%
df['horsepower']=df['horsepower'].astype("float")

# %% [markdown]
# **Learn more about your dataset**

# %%
df['weight'].min()
# Out:
# 1773.0

# %%
df['weight'].round()
# Out:
# 0     3504.0
# 1     3693.0
# 2     3436.0
# 3     3433.0
# 4     3449.0
#        ...
# 93    4237.0
# 94    4735.0
# 95       NaN
# 96    3821.0
# 97    3121.0
# Name: weight, Length: 90, dtype: float64

# %%
df['weight'].max()
# Out:
# 5140.0

# %%
df['weight'].median()
# Out:
# 3436.0

# %%
df.describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  90.000000  90.000000     90.000000   90.000000    87.000000
# mean   18.011111   6.388889    259.838889  131.911111  3364.689655
# std     5.474136   1.846311    122.705270   47.292692   950.308179
# min     9.000000   3.000000     70.000000   46.000000  1773.000000
# 25%    14.000000   4.000000    121.000000   90.000000  2401.500000
# 50%    16.500000   8.000000    303.000000  138.500000  3436.000000
# 75%    22.000000   8.000000    350.750000  165.000000  4223.000000
# max    31.000000   8.000000    455.000000  225.000000  5140.000000
#
#        acceleration  model year     origin
# count     88.000000   88.000000  90.000000
# mean      14.034091   71.318182   1.322222
# std        2.993091    1.056403   0.632949
# min        8.000000   70.000000   1.000000
# 25%       12.000000   70.000000   1.000000
# 50%       13.500000   71.000000   1.000000
# 75%       15.500000   72.000000   1.000000
# ...

# %%
# Value_Counts()

# DataFrame.value_counts(subset=None, normalize=False, sort=True, ascending=False, dropna=True)[source]
# Return a Series containing counts of unique rows in the DataFrame.
df['carname'].value_counts()
# Out:
# ford galaxie 500             3
# chevrolet impala             3
# plymouth fury iii            3
# chevrolet chevelle malibu    2
# amc gremlin                  2
#                             ..
# pontiac catalina brougham    1
# ford torino 500              1
# plymouth satellite custom    1
# chevrolet vega 2300          1
# plymouth valiant             1
# Name: carname, Length: 80, dtype: int64

# %%
# #	Display the first five and last five rows
# 	Display all the column names in the dataset
# 	Display the concise summary of your dataset
# 	Display the name of the car with maximum number of horsepower.

# df.head()
# df.tail()
# df.describe()
# df2 = df [['carname','horsepower']][df.horsepower==df['horsepower'].max()]


df2=df[['carname','horsepower']][df.horsepower==df['horsepower'].max()]
df2
# Out:
#                      carname  horsepower
# 8           pontiac catalina       225.0
# 13   buick estate wagon (sw)       225.0
# 95  buick electra 225 custom       225.0

# %%
# Standard deviation is the measure of how spread out numbers are.
# Pandas is a library in Python that is used to calculate the standard deviation.

# In Maths, the mean is defined as the average of all the given values.
# It means that the sum of all the given values divided by the total number of values given.
# Whereas, the standard deviation is considered as the measure of the dispersion of the data values from the mean.

#The dispersion is the difference between the actual value and the average value in a set.
#Basically, the wider the dispersion, the higher the standard deviation.
#SD can range from 0 to infinity. Getting a 0 indicates that a set of numbers are all equal,
#which signifies they don’t spread apart to any degree at all.

import pandas as pd
s=[5,5,5,5,5,5,5,5]
df=pd.DataFrame(s)
df.describe()
# Out:
#          0
# count  8.0
# mean   5.0
# std    0.0
# min    5.0
# 25%    5.0
# 50%    5.0
# 75%    5.0
# max    5.0

# %% [markdown]
# https://www.calculators.org/math/standard-deviation.php

# %% [markdown]
# **NORMALIZATION**
#
# This normalization can make some statistical analysis easier down the road.
# By making the ranges consistent between variables, normalization enables a fair comparison between the different features, making sure they have the same impact. It is also important for computational reasons

# %% [markdown]
#  example: there’s a dataset with two variables, height (cm) and weight (kg). The most obvious problem is that the variables are measured in different units: one in cm and the other in kg. This impacts the distribution. To solve the issue, normalization is used to transform the data in such a way that either is dimensionless or has similar distributions. This process of normalization is known by other names such as feature scaling, standardization, etc.

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
#absolute max normalization
# The maximum absolute scaling rescales each feature between -1 and 1 by dividing every observation by its maximum absolute value.
#  We can apply the maximum absolute scaling in Pandas using the .max() and .abs() methods.

df['horsepower'] = df['horsepower'] /df['horsepower'].abs().max()

df2=df.head(10)
df2
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0    0.577778  3504.0          12.0        70.0
# 1   15          8         350.0    0.733333  3693.0          11.5        70.0
# 2   18          8         318.0    0.666667  3436.0          11.0        70.0
# 3   16          8         304.0    0.666667  3433.0          12.0        70.0
# 4   17          8         302.0    0.622222  3449.0          10.5        70.0
# 5   15          8         429.0    0.880000  4341.0          10.0        70.0
# 6   14          8         454.0    0.977778  4354.0           9.0        70.0
# 7   14          8         440.0    0.955556  4312.0           8.5        70.0
# 8   14          8         455.0    1.000000     NaN          10.0        70.0
# 9   15          8         390.0    0.844444  3850.0           8.5        70.0
#
#    origin                   car name CAR Number
# 0       1  chevrolet chevelle malibu    L6V 043
# ...

# %%
#Apply min max normalization

# Example: The machine learning algorithm should realize that there is a huge difference between a house with 2 rooms and a house with 20 rooms.
# But right now, because two houses can be 100 years apart, the difference in the number of rooms contributes less to the overall difference.

# The goal of normalization is to make every datapoint have the same scale so each feature is equally important.



df['horsepower'] = (df['horsepower'] - df['horsepower'].min()) / (df['horsepower'].max() - df['horsepower'].min())

# %% [markdown]
# **ZSCORE**

# %%
# Min-max normalization has one fairly significant downside: it does not handle outliers very well.
#The z-score method (often called standardization) transforms the info into distribution with a mean of 0 and a typical deviation of 1.
#Each standardized value is computed by subtracting the mean of the corresponding feature then dividing by the quality deviation.

# %% [markdown]
# Z-score normalization is a strategy of normalizing data that avoids this outlier issue. The formula for Z-score normalization is below:
# In statistics, a z-score tells us how many standard deviations away a value is from the mean. We use the following formula to calculate a z-score:
#
# z = (X – μ) / σ
#
# where:
# X is a single raw data value
#
# μ is the population mean
#
# σ is the population standard deviation
#
#
#
# Therefore, any z-score greater than +3 or less than -3 is considered as outlier which is pretty much similar to standard deviation method.

# %%
#ZSCORE ... HOW MANY STD DEVIATION YOU ARE AWAY FROM THE MEAN
df['ZSCORE']= (df.acceleration-df.acceleration.mean())/df['acceleration'].std()

# %%
df
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0    0.577778  3504.0          12.0
# 1    15          8         350.0    0.733333  3693.0          11.5
# 2    18          8         318.0    0.666667  3436.0          11.0
# 3    16          8         304.0    0.666667  3433.0          12.0
# 4    17          8         302.0    0.622222  3449.0          10.5
# ..  ...        ...           ...         ...     ...           ...
# 93   14          8         318.0    0.666667  4237.0          14.5
# 94   13          8         440.0    0.955556  4735.0          11.0
# 95   12          8         455.0    1.000000     NaN          11.0
# 96   13          8         360.0    0.777778  3821.0          11.0
# 97   18          6         225.0    0.466667  3121.0          16.5
#
#     model year  origin                      car name CAR Number    ZSCORE
# 0         70.0       1     chevrolet chevelle malibu    L6V 043 -0.677148
# ...

# %%
df[df['ZSCORE']>2.5]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 59   23          4          97.0        0.24  2254.0          23.5
#
#     model year  origin           car name CAR Number    ZSCORE
# 59        72.0       2  volkswagen type 3     ERT566  3.127286

# %%
df[df['ZSCORE']<-2]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14          8         340.0    0.711111  3609.0           8.0
#
#     model year  origin            car name CAR Number    ZSCORE
# 11        70.0       1  plymouth 'cuda 340     TN5679 -2.000429

# %% [markdown]
# **BINNING**
#
# Converting numeric values to Categorical values
#
# Grouping values into bins
#
# Convert numeric into categorical variables
#
# After data has been put into bins, what would be the best graph to use to visualize the data?

# %% [markdown]
# Data binning, bucketing is a data pre-processing method used to minimize the effects of observation errors. Binning is the process of transforming numerical variables into categorical counterparts.
#
#
# Binning improves accuracy of the predictive models by reducing the noise or non-linearity in the dataset. Finally, binning lets easy identification of outliers, invalid and missing values of numerical variables.
#
#
# Binning is a quantization technique in Machine Learning to handle continuous variables. It is one of the important steps in Data Wrangling.

# %% [markdown]
# **Binning by distance is achieved by means of the cut() function.**

# %%
import numpy as np
#np.linspace() has two required parameters, start and stop, which you can use to set the beginning and end of the range:
#creates evenly spaces array
bins=np.linspace(min(df["acceleration"]), max(df["acceleration"]), 4)
print(bins)
groupnames=['low','medium','high']
# Out:
# [ 8.         13.16666667 18.33333333 23.5       ]

# %%
df['acccategories']= pd.cut(df['acceleration'],bins,labels=groupnames)
df['acccategories'].value_counts()
# Out:
# medium    46
# low       39
# high      10
# Name: acccategories, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.bar(["low","medium","high"],df["accqcut"].value_counts())
plt.xlabel("acccategories",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("accelration bins",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(["low","medium","high"],df["acccategories"].value_counts())
plt.xlabel("acccategories",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("accelration bins",fontsize=15)
plt.show()

# %% [markdown]
# **BINNING BY FREQUENCY**
#
# Binning by frequency calculates the size of each bin so that each bin contains the (almost) same number of observations, but the bin range will vary. We can use the Python pandas qcut() function. We can set the precision parameter to define the number of decimal points.

# %%
# The pandas documentation describes qcut as a “Quantile-based discretization function.”
# This basically means that qcut tries to divide up the underlying data into equal sized bins.
# The function defines the bins using percentiles based on the distribution of the data, not the actual numeric edges of the bins.

df['accqcut']=pd.qcut(df['acceleration'], q=3)

# %%
df['accqcut'].value_counts()
# Out:
# (7.999, 12.5]    34
# (12.5, 15.0]     32
# (15.0, 23.5]     30
# Name: accqcut, dtype: int64

# %%
df['acccategories'].value_counts()
# Out:
# medium    46
# low       39
# high      10
# Name: acccategories, dtype: int64

# %%
binlabels = ['Silver', 'Gold', 'Diamond']
df['accqcut2'] = pd.qcut(df['acceleration'],
                              q=[0, .4, .8, 1],
                              labels=binlabels)
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0    0.577778  3504.0          12.0        70.0
# 1   15          8         350.0    0.733333  3693.0          11.5        70.0
# 2   18          8         318.0    0.666667  3436.0          11.0        70.0
# 3   16          8         304.0    0.666667  3433.0          12.0        70.0
# 4   17          8         302.0    0.622222  3449.0          10.5        70.0
#
#    origin                   car name CAR Number    ZSCORE acccategories  \
# 0       1  chevrolet chevelle malibu    L6V 043 -0.677148           low
# 1       1          buick skylark 320     RTY079 -0.842558           low
# 2       1         plymouth satellite     MTP600 -1.007968           low
# 3       1              amc rebel sst     MNJ000 -0.677148           low
# 4       1                ford torino   JEETMEET -1.173378           low
#
#          accqcut accqcut2
# 0  (7.999, 12.5]   Silver
# ...

# %% [markdown]
# In our dataset, "horsepower" is a real valued variable ranging from 48 to 288, it has 57 unique values.
#
# What if we only care about the price difference between cars with high horsepower, medium horsepower, and little horsepower (3 types)?
#
# Can we rearrange them into three ‘bins' to simplify analysis?
# We will use the Pandas method 'cut' to segment the 'horsepower' column into 3 bins

# %%
# Categories  binning

df.replace("?", np.nan, inplace = True)
df.dropna(inplace = True)
df["horsepower"]=df["horsepower"].astype(int, copy=True)
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")

# %%
group_names = ['Low', 'Medium', 'High']
#We apply the function "cut" the determine what each value of "df['horsepower']" belongs to.

df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)

# %%
#oTHER WAY TO FIND ZSCORE

import scipy.stats as stats
values = [4,5,6,6,6,7,8,12,13,13,14,18]
#it can not work with na values so drop it before running this
zscores = stats.zscore(df['acceleration'])
print(zscores)

# %%
# Detect outliers using Z-score and remove them
#Z Score
from scipy import stats

df['zscore']=stats.zscore(df["acceleration"])
#outlier=np.where(score>3)
df.loc[df['zscore'].abs()>2]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, car name, CAR Number, zscore]
# Index: []
